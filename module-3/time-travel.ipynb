# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/time-travel.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239536-lesson-5-time-travel)

# %% [markdown]
# # Time travel
#
# ## Review
#
# We discussed motivations for human-in-the-loop:
#
# (1) `Approval` - We can interrupt our agent, surface state to a user, and allow the user to accept an action
#
# (2) `Debugging` - We can rewind the graph to reproduce or avoid issues
#
# (3) `Editing` - You can modify the state
#
# We showed how breakpoints can stop the graph at specific nodes or allow the graph to dynamically interrupt itself.
#
# Then we showed how to proceed with human approval or directly edit the graph state with human feedback.
#
# ## Goals
#
# Now, let's show how LangGraph [supports debugging](https://docs.langchain.com/oss/python/langgraph/use-time-travel) by viewing, re-playing, and even forking from past states.
#
# We call this `time travel`.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk langgraph-prebuilt

# %%
import os, getpass
from dotenv import load_dotenv
load_dotenv()
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langchain-academy"

# %% [markdown]
# Let's build our agent.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

def multiply(a: int, b: int) -> int:
    """Multiply a and b.

    Args:
        a: first int
        b: second int
    """
    return a * b

# This will be a tool
def add(a: int, b: int) -> int:
    """Adds a and b.

    Args:
        a: first int
        b: second int
    """
    return a + b

def divide(a: int, b: int) -> float:
    """Divide a by b.

    Args:
        a: first int
        b: second int
    """
    return a / b

tools = [add, multiply, divide]
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
llm_with_tools = llm.bind_tools(tools)

# %%
from IPython.display import Image, display

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import MessagesState
from langgraph.graph import START, END, StateGraph
from langgraph.prebuilt import tools_condition, ToolNode

from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

# System message
sys_msg = "You are a helpful assistant tasked with performing arithmetic on a set of inputs."

# Node
def assistant(state: MessagesState):
   return {"messages": [llm_with_tools.invoke([sys_msg] + state["messages"])]}

# Graph
builder = StateGraph(MessagesState)

# Define nodes: these do the work
builder.add_node("assistant", assistant)
builder.add_node("tools", ToolNode(tools))

# Define edges: these determine the control flow
builder.add_edge(START, "assistant")
builder.add_conditional_edges(
    "assistant",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition,
)
builder.add_edge("tools", "assistant")

memory = MemorySaver()
graph = builder.compile(checkpointer=MemorySaver())

# Show
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# Let's run it, as before.

# %%
# Input
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}

# Thread
thread = {"configurable": {"thread_id": "1"}}

# Run the graph until the first interruption
for event in graph.stream(initial_input, thread, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (75653dbb-90b3-4ec6-8f0d-05c4c7bd08f4)
#  Call ID: 75653dbb-90b3-4ec6-8f0d-05c4c7bd08f4
#   Args:
#     b: 3
#     a: 2
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The product of 2 and 3 is 6.

# %% [markdown]
# ## Browsing History
#
# We can use `get_state` to look at the **current** state of our graph, given the `thread_id`!

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='f4606153-6cc8-454b-802e-767b830beda4'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"b": 3, "a": 2}'}, '__gemini_function_call_thought_signatures__': {'75653dbb-90b3-4ec6-8f0d-05c4c7bd08f4': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ef0d7-26c0-7841-8546-4b1912c783ac-0', tool_calls=[{'name': 'multiply', 'args': {'b': 3, 'a': 2}, 'id': '75653dbb-90b3-4ec6-8f0d-05c4c7bd08f4', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 65, 'total_tokens': 232, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 47}}), ToolMessage(content='6', name='multiply', id='69963407-4925-444f-baaa-b0ff54013c40', tool_call_id='75653dbb-90b3-4ec6-8f0d-05c4c7bd08f4'), AIMessage(content='The product of 2 and 3 is 6.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ef0d7-2a48-7061-a498-8aaa54d6abb9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 198, 'output_tokens': 12, 'total_tokens': 210, 'input_token_details': {'cache_read': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-8bcd-65a2-8003-4599f4fa918e'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-22T19:38:14.024531+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-864b-6cdc-8002-db1069dfd82d'}}, tasks=(), interrupts=())

# %% [markdown]
# We can also browse the state history of our agent.
#
# `get_state_history` lets us get the state at all prior steps.

# %%
all_states = [s for s in graph.get_state_history(thread)]

# %%
len(all_states)
# Out:
# 5

# %% [markdown]
# The first element is the current state, just as we got from `get_state`.

# %%
all_states[-2]
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='f4606153-6cc8-454b-802e-767b830beda4')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-7dab-6c8a-8000-240c588b57c7'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-22T19:38:12.542777+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-7da9-661a-bfff-9daa5f0633bf'}}, tasks=(PregelTask(id='b92ae467-e5e5-6ae3-73b5-3509efba84ba', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"b": 3, "a": 2}'}, '__gemini_function_call_thought_signatures__': {'75653dbb-90b3-4ec6-8f0d-05c4c7bd08f4': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ef0d7-26c0-7841-8546-4b1912c783ac-0', tool_calls=[{'name': 'multiply', 'args': {'b': 3, 'a': 2}, 'id': '75653dbb-90b3-4ec6-8f0d-05c4c7bd08f4', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 65, 'total_tokens': 232, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 47}})]}),), interrupts=())

# %% [markdown]
# Everything above we can visualize here:
#
# ![fig1.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038211b544898570be3_time-travel1.png)

# %% [markdown]
# ## Replaying
#
# We can re-run our agent from any of the prior steps.
#
# ![fig2.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038a0bd34b541c78fb8_time-travel2.png)

# %% [markdown]
# Let's look back at the step that recieved human input!

# %%
to_replay = all_states[-2]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='f4606153-6cc8-454b-802e-767b830beda4')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-7dab-6c8a-8000-240c588b57c7'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-22T19:38:12.542777+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-7da9-661a-bfff-9daa5f0633bf'}}, tasks=(PregelTask(id='b92ae467-e5e5-6ae3-73b5-3509efba84ba', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"b": 3, "a": 2}'}, '__gemini_function_call_thought_signatures__': {'75653dbb-90b3-4ec6-8f0d-05c4c7bd08f4': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ef0d7-26c0-7841-8546-4b1912c783ac-0', tool_calls=[{'name': 'multiply', 'args': {'b': 3, 'a': 2}, 'id': '75653dbb-90b3-4ec6-8f0d-05c4c7bd08f4', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 65, 'total_tokens': 232, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 47}})]}),), interrupts=())

# %% [markdown]
# Look at the state.

# %%
to_replay.values
# Out:
# {'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='f4606153-6cc8-454b-802e-767b830beda4')]}

# %% [markdown]
# We can see the next node to call.

# %%
to_replay.next
# Out:
# ('assistant',)

# %% [markdown]
# We also get the config, which tells us the `checkpoint_id` as well as the `thread_id`.

# %%
to_replay.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f16e71e-7dab-6c8a-8000-240c588b57c7'}}

# %% [markdown]
# To replay from here, we simply pass the config back to the agent!
#
# The graph knows that this checkpoint has aleady been executed.
#
# It just re-plays from this checkpoint!

# %%
for event in graph.stream(None, to_replay.config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (58d9d817-4e41-46e0-926a-3dbc4965e573)
#  Call ID: 58d9d817-4e41-46e0-926a-3dbc4965e573
#   Args:
#     b: 3
#     a: 2
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The product of 2 and 3 is 6.

# %% [markdown]
# Now, we can see our current state after the agent re-ran.

# %% [markdown]
# ## Forking
#
# What if we want to run from that same step, but with a different input.
#
# This is forking.
#
# ![fig3.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038f89f2d847ee5c336_time-travel3.png)

# %%
to_fork = all_states[-2]
to_fork.values["messages"]
# Out:
# [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='f4606153-6cc8-454b-802e-767b830beda4')]

# %% [markdown]
# Again, we have the config.

# %%
to_fork.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f16e71e-7dab-6c8a-8000-240c588b57c7'}}

# %% [markdown]
# Let's modify the state at this checkpoint.
#
# We can just run `update_state` with the `checkpoint_id` supplied.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!
#
# So, to overwrite the the message, we just supply the message ID, which we have `to_fork.values["messages"].id`.

# %%
fork_config = graph.update_state(
    to_fork.config,
    {"messages": [HumanMessage(content='Multiply 5 and 3', 
                               id=to_fork.values["messages"][0].id)]},
) #supply fork-id <- overwrite 
#add-messages reducer <- append, no-id, overwrite-if id

# %%
fork_config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f16e71e-99f0-6076-8001-634de267495e'}}

# %% [markdown]
# This creates a new, forked checkpoint.
#
# But, the metadata - e.g., where to go next - is perserved!
#
# We can see the current state of our agent has been updated with our fork.

# %%
all_states = [state for state in graph.get_state_history(thread) ]
all_states[0].values["messages"]
len(all_states)
# Out:
# 13

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='f4606153-6cc8-454b-802e-767b830beda4')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-99f0-6076-8001-634de267495e'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2026-06-22T19:38:15.506741+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-7dab-6c8a-8000-240c588b57c7'}}, tasks=(PregelTask(id='85e45499-ca84-7840-e805-6e5c06405dbb', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %% [markdown]
# Now, when we stream, the graph knows this checkpoint has never been executed.
#
# So, the graph runs, rather than simply re-playing.

# %%
for event in graph.stream(None, fork_config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 5 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (085e302f-cd67-475c-82a6-26f9c78e2b65)
#  Call ID: 085e302f-cd67-475c-82a6-26f9c78e2b65
#   Args:
#     a: 5
#     b: 3
# ================================= Tool Message =================================
# Name: multiply
#
# 15
# ================================== Ai Message ==================================
#
# The product of 5 and 3 is 15.

# %% [markdown]
# Now, we can see the current state is the end of our agent run.

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='f4606153-6cc8-454b-802e-767b830beda4'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"a": 5, "b": 3}'}, '__gemini_function_call_thought_signatures__': {'085e302f-cd67-475c-82a6-26f9c78e2b65': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ef0d7-3287-7c41-b693-ec7aff29dc7f-0', tool_calls=[{'name': 'multiply', 'args': {'a': 5, 'b': 3}, 'id': '085e302f-cd67-475c-82a6-26f9c78e2b65', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 79, 'total_tokens': 246, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 61}}), ToolMessage(content='15', name='multiply', id='6eb00340-c7fd-428e-9573-ed1450a5eeb8', tool_call_id='085e302f-cd67-475c-82a6-26f9c78e2b65'), AIMessage(content='The product of 5 and 3 is 15.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ef0d7-35eb-73d3-a708-df36b95efaf6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 13, 'total_tokens': 212, 'input_token_details': {'cache_read': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-a7aa-6612-8004-13c915a72d0c'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-22T19:38:16.946221+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16e71e-a2b4-6248-8003-769739e7780d'}}, tasks=(), interrupts=())

# %% [markdown]
# ### Time travel with LangGraph API
#
# **⚠️ Notice**
#
# Since filming these videos, we've updated Studio so that it can now be run locally and accessed through your browser. This is the preferred way to run Studio instead of using the Desktop App shown in the video. It is now called _LangSmith Studio_ instead of _LangGraph Studio_. Detailed setup instructions are available in the "Getting Setup" guide at the start of the course. You can find a description of Studio [here](https://docs.langchain.com/langsmith/studio), and specific details for local deployment [here](https://docs.langchain.com/langsmith/quick-start-studio#local-development-server).
# To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the **Studio UI** URL shown above.
#
# We connect to it via the SDK and show how the LangGraph API [supports time travel](https://docs.langchain.com/langsmith/human-in-the-loop-time-travel).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client
client = get_client(url="http://127.0.0.1:2024")

# %% [markdown]
# #### Re-playing
#
# Let's run our agent streaming `updates` to the state of the graph after each node is called.

# %%
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id = "agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'function_call': {'name': 'multiply', 'arguments': '{"a": 2, "b": 3}'}, '__gemini_function_call_thought_signatures__': {'07fc5752-41d2-41d6-8a21-0e7ca0adb3c3': ''}}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0dd-1dac-7622-a4ae-ed6d913e2679-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '07fc5752-41d2-41d6-8a21-0e7ca0adb3c3', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 170, 'output_tokens': 78, 'total_tokens': 248, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 60}}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '6703161d-d854-4b2e-9815-05675e7a9580', 'tool_call_id': '07fc5752-41d2-41d6-8a21-0e7ca0adb3c3', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The product of 2 and 3 is 6.', 'additional_kwargs': {}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0dd-2196-79b3-a1c1-276e71835244-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 201, 'output_tokens': 12, 'total_tokens': 213, 'input_token_details': {'cache_read': 0}}}

# %% [markdown]
# Now, let's look at **replaying** from a specified checkpoint.
#
# We simply need to pass the `checkpoint_id`.

# %%
states = await client.threads.get_history(thread['thread_id'])
to_replay = states[-2]
to_replay
# Out:
# {'values': {'messages': [{'content': 'Multiply 2 and 3',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': '48dd51a6-c541-4aa8-8c56-7df59b35830b'}]},
#  'next': ['assistant'],
#  'tasks': [{'id': '4726623e-413a-778f-f940-c0ca5a1b8b4c',
#    'name': 'assistant',
#    'path': ['__pregel_pull', 'assistant'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': {'messages': [{'content': '',
#       'additional_kwargs': {'function_call': {'name': 'multiply',
#         'arguments': '{"a": 2, "b": 3}'},
#        '__gemini_function_call_thought_signatures__': {'07fc5752-41d2-41d6-8a21-0e7ca0adb3c3': ''}},
#       'response_metadata': {'finish_reason': 'STOP',
#        'model_name': 'gemini-2.5-flash',
#        'safety_ratings': [],
#        'model_provider': 'google_genai'},
#       'type': 'ai',
#       'name': None,
#       'id': 'lc_run--019ef0dd-1dac-7622-a4ae-ed6d913e2679-0',
#       'tool_calls': [{'name': 'multiply',
#         'args': {'a': 2, 'b': 3},
#         'id': '07fc5752-41d2-41d6-8a21-0e7ca0adb3c3',
#         'type': 'tool_call'}],
#       'invalid_tool_calls': [],
#       'usage_metadata': {'input_tokens': 170,
#        'output_tokens': 78,
#        'total_tokens': 248,
#        'input_token_details': {'cache_read': 0},
#        'output_token_details': {'reasoning': 60}}}]}}],
#  'metadata': {'graph_id': 'agent',
#   'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#   'user_id': '',
#   'created_by': 'system',
#   'run_attempt': 1,
#   'langgraph_version': '1.2.6',
#   'langgraph_api_version': '0.10.0',
#   'langgraph_plan': 'enterprise',
#   'langgraph_host': 'self-hosted',
#   'langgraph_api_url': 'http://127.0.0.1:2024',
#   'run_id': '019ef0dd-1963-76e1-a68a-4103f8e806d3',
#   'thread_id': '019ef0dd-195f-7230-817c-223f99888aa6',
#   'source': 'loop',
#   'step': 0,
#   'parents': {},
#   'langgraph_auth_user_id': '',
#   'langgraph_request_id': 'b821ea79-a358-4c29-85e5-5dc97f200fcf'},
#  'created_at': '2026-06-22T19:44:43.360896+00:00',
#  'checkpoint': {'checkpoint_id': '1f16e72d-0ccd-6950-8000-f80e1d372c41',
#   'thread_id': '019ef0dd-195f-7230-817c-223f99888aa6',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f16e72d-0cc8-677a-bfff-5c7ce1811c70',
#   'thread_id': '019ef0dd-195f-7230-817c-223f99888aa6',
#   'checkpoint_ns': ''},
#  'interrupts': [],
#  'checkpoint_id': '1f16e72d-0ccd-6950-8000-f80e1d372c41',
#  'parent_checkpoint_id': '1f16e72d-0cc8-677a-bfff-5c7ce1811c70'}

# %% [markdown]
# Let's stream with `stream_mode="values"` to see the full state at every node as we replay.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="values",
    checkpoint_id=to_replay['checkpoint_id']
):      
    print(f"Receiving new event of type: {chunk.event}...")
    print(chunk.data)
    print("\n\n")
# Out:
# Receiving new event of type: metadata...
# {'run_id': '019ef0dd-c360-7392-ac45-406776d85d7c', 'attempt': 1}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '48dd51a6-c541-4aa8-8c56-7df59b35830b'}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '48dd51a6-c541-4aa8-8c56-7df59b35830b'}, {'content': '', 'additional_kwargs': {'function_call': {'name': 'multiply', 'arguments': '{"b": 3, "a": 2}'}, '__gemini_function_call_thought_signatures__': {'b2aa8a03-ca66-4830-9ada-2174b9adc7ed': ''}}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0dd-c658-7422-ad57-801a88aa9d08-0', 'tool_calls': [{'name': 'multiply', 'args': {'b': 3, 'a': 2}, 'id': 'b2aa8a03-ca66-4830-9ada-2174b9adc7ed', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 170, 'output_tokens': 79, 'total_tokens': 249, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 61}}}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '48dd51a6-c541-4aa8-8c56-7df59b35830b'}, {'content': '', 'additional_kwargs': {'function_call': {'name': 'multiply', 'arguments': '{"b": 3, "a": 2}'}, '__gemini_function_call_thought_signatures__': {'b2aa8a03-ca66-4830-9ada-2174b9adc7ed': ''}}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0dd-c658-7422-ad57-801a88aa9d08-0', 'tool_calls': [{'name': 'multiply', 'args': {'b': 3, 'a': 2}, 'id': 'b2aa8a03-ca66-4830-9ada-2174b9adc7ed', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 170, 'output_tokens': 79, 'total_tokens': 249, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 61}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'e43b4cda-12be-4b67-9602-7e43da2c1e2b', 'tool_call_id': 'b2aa8a03-ca66-4830-9ada-2174b9adc7ed', 'artifact': None, 'status': 'success'}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '48dd51a6-c541-4aa8-8c56-7df59b35830b'}, {'content': '', 'additional_kwargs': {'function_call': {'name': 'multiply', 'arguments': '{"b": 3, "a": 2}'}, '__gemini_function_call_thought_signatures__': {'b2aa8a03-ca66-4830-9ada-2174b9adc7ed': ''}}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0dd-c658-7422-ad57-801a88aa9d08-0', 'tool_calls': [{'name': 'multiply', 'args': {'b': 3, 'a': 2}, 'id': 'b2aa8a03-ca66-4830-9ada-2174b9adc7ed', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 170, 'output_tokens': 79, 'total_tokens': 249, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 61}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'e43b4cda-12be-4b67-9602-7e43da2c1e2b', 'tool_call_id': 'b2aa8a03-ca66-4830-9ada-2174b9adc7ed', 'artifact': None, 'status': 'success'}, {'content': 'The product of 2 and 3 is 6.', 'additional_kwargs': {}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0dd-ca8d-7463-b4a0-0a8ec2d2eaa8-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 201, 'output_tokens': 12, 'total_tokens': 213, 'input_token_details': {'cache_read': 0}}}]}

# %% [markdown]
# We can all view this as streaming only `updates` to state made by the nodes that we reply.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=to_replay['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'function_call': {'name': 'multiply', 'arguments': '{"a": 2, "b": 3}'}, '__gemini_function_call_thought_signatures__': {'a5590505-adf4-4836-9501-b7bdeacd93a7': ''}}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0de-0b20-7173-abaa-129ab0380a28-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'a5590505-adf4-4836-9501-b7bdeacd93a7', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 170, 'output_tokens': 81, 'total_tokens': 251, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 63}}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '1cf459bd-d6c2-45d9-bd2c-bb1d4eeb80ac', 'tool_call_id': 'a5590505-adf4-4836-9501-b7bdeacd93a7', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The product of 2 and 3 is 6.', 'additional_kwargs': {}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0de-0f49-7131-997d-b3877cf95ed7-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 201, 'output_tokens': 12, 'total_tokens': 213, 'input_token_details': {'cache_read': 0}}}

# %% [markdown]
# #### Forking
#
# Now, let's look at forking.
#
# Let's get the same step as we worked with above, the human input.
#
# Let's create a new thread with our agent.

# %%
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'function_call': {'name': 'multiply', 'arguments': '{"a": 2, "b": 3}'}, '__gemini_function_call_thought_signatures__': {'23994107-a651-4e5b-9018-bd7475e43a10': ''}}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0de-f096-7402-8f58-273df0922ea2-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '23994107-a651-4e5b-9018-bd7475e43a10', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 170, 'output_tokens': 78, 'total_tokens': 248, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 60}}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '3321ec02-0a4c-42a9-8536-ff5ce2a249cf', 'tool_call_id': '23994107-a651-4e5b-9018-bd7475e43a10', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0de-f72c-7693-b52e-789bc413619e-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 201, 'output_tokens': 13, 'total_tokens': 214, 'input_token_details': {'cache_read': 0}}}

# %%
states = await client.threads.get_history(thread['thread_id'])
to_fork = states[-2]
to_fork['values']
# Out:
# {'messages': [{'content': 'Multiply 2 and 3',
#    'additional_kwargs': {},
#    'response_metadata': {},
#    'type': 'human',
#    'name': None,
#    'id': '87bb3ab9-1bee-4294-99da-3b0561a84306'}]}

# %%
to_fork['values']['messages'][0]['id']
# Out:
# '87bb3ab9-1bee-4294-99da-3b0561a84306'

# %%
to_fork['next']
# Out:
# ['assistant']

# %%
to_fork['checkpoint_id']
# Out:
# '1f16e731-816d-6d7e-8000-91113bdfc3c8'

# %% [markdown]
# Let's edit the state.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!

# %%
forked_input = {"messages": HumanMessage(content="Multiply 3 and 3",
                                         id=to_fork['values']['messages'][0]['id'])}

forked_config = await client.threads.update_state(
    thread["thread_id"],
    forked_input,
    checkpoint_id=to_fork['checkpoint_id']
)

# %%
forked_config #new checkpoint to fork from
# Out:
# {'checkpoint': {'thread_id': '019ef0de-edf6-77a2-a157-c837db300048',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f16e738-088c-6980-8001-8db353c2e8cc'},
#  'configurable': {'thread_id': '019ef0de-edf6-77a2-a157-c837db300048',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f16e738-088c-6980-8001-8db353c2e8cc'},
#  'checkpoint_id': '1f16e738-088c-6980-8001-8db353c2e8cc'}

# %%
states = await client.threads.get_history(thread['thread_id'])
states[0]
# Out:
# {'values': {'messages': [{'content': 'Multiply 3 and 3',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': '87bb3ab9-1bee-4294-99da-3b0561a84306'}]},
#  'next': ['assistant'],
#  'tasks': [{'id': 'dd23c481-7486-8c02-1898-09db5b504674',
#    'name': 'assistant',
#    'path': ['__pregel_pull', 'assistant'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': None}],
#  'metadata': {'graph_id': 'agent',
#   'checkpoint_id': '1f16e731-816d-6d7e-8000-91113bdfc3c8',
#   'thread_id': '019ef0de-edf6-77a2-a157-c837db300048',
#   'source': 'update',
#   'step': 1,
#   'parents': {}},
#  'created_at': '2026-06-22T19:49:38.193836+00:00',
#  'checkpoint': {'checkpoint_id': '1f16e738-088c-6980-8001-8db353c2e8cc',
#   'thread_id': '019ef0de-edf6-77a2-a157-c837db300048',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f16e731-816d-6d7e-8000-91113bdfc3c8',
#   'thread_id': '019ef0de-edf6-77a2-a157-c837db300048',
#   'checkpoint_ns': ''},
#  'interrupts': [],
#  'checkpoint_id': '1f16e738-088c-6980-8001-8db353c2e8cc',
#  'parent_checkpoint_id': '1f16e731-816d-6d7e-8000-91113bdfc3c8'}

# %% [markdown]
# To rerun, we pass in the `checkpoint_id`.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=forked_config['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'function_call': {'name': 'multiply', 'arguments': '{"a": 3, "b": 3}'}, '__gemini_function_call_thought_signatures__': {'f357a2de-3d60-4350-92ff-9f2c4e712be0': ''}}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0e2-2069-75a0-ae5f-ed7b1736ae10-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 3, 'b': 3}, 'id': 'f357a2de-3d60-4350-92ff-9f2c4e712be0', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 170, 'output_tokens': 81, 'total_tokens': 251, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 63}}}
# --------------------Tools Node--------------------
# {'content': '9', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '4fbbb125-32d1-4f19-bca2-55fce790f259', 'tool_call_id': 'f357a2de-3d60-4350-92ff-9f2c4e712be0', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The result of multiplying 3 and 3 is 9.', 'additional_kwargs': {}, 'response_metadata': {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ef0e2-247c-7a11-a7ec-cbc765693d6f-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 201, 'output_tokens': 13, 'total_tokens': 214, 'input_token_details': {'cache_read': 0}}}

# %% [markdown]
# ### LangGraph Studio
#
# Let's look at forking in the Studio UI with our `agent`, which uses `module-1/studio/agent.py` set in `module-1/studio/langgraph.json`.
